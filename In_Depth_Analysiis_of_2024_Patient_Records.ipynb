# %%
import pandas as pd
df= r'/content/Desmond_Healthcare_Data_2024.xlsx'
df= pd.read_excel(df)
df.head()
# Out:
#    Patient_ID  Age  Gender Visit_Date     Diagnosis  Treatment_Cost Branch  \
# 0        1001   32    Male 2024-05-20      Diabetes           17844  Abuja
# 1        1002   29  Female 2024-01-17  Hypertension           12777  Lagos
# 2        1003   43  Female 2024-04-22        Asthma            8789  Enugu
# 3        1004   72  Female 2024-05-22      Diabetes           19684  Abuja
# 4        1005   63  Female 2024-11-05       Malaria            2859  Lagos
#
#         Doctor_Name  Length_of_Stay Readmitted    Outcome
# 0      Dr. Z. Mordi               2         No  Recovered
# 1      Dr. Z. Mordi               5         No  Recovered
# 2    Dr. N. Adebayo               2         No  Recovered
# 3       Dr. E. Uche               4        Yes  Recovered
# 4  Dr. M. Onyekwere               3         No   Deceased
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      200 non-null    int64
#  1   Age             200 non-null    int64
#  2   Gender          200 non-null    object
#  3   Visit_Date      200 non-null    datetime64[ns]
#  4   Diagnosis       200 non-null    object
#  5   Treatment_Cost  200 non-null    int64
#  6   Branch          200 non-null    object
#  7   Doctor_Name     200 non-null    object
#  8   Length_of_Stay  200 non-null    int64
#  9   Readmitted      200 non-null    object
#  10  Outcome         200 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 17.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Patient_ID                 int64
# Age                        int64
# Gender                    object
# Visit_Date        datetime64[ns]
# Diagnosis                 object
# Treatment_Cost             int64
# Branch                    object
# Doctor_Name               object
# Length_of_Stay             int64
# Readmitted                object
# Outcome                   object
# dtype: object

# %%
len(df)
# Out:
# 200

# %%
df.isnull().sum()
# Out:
# Patient_ID        0
# Age               0
# Gender            0
# Visit_Date        0
# Diagnosis         0
# Treatment_Cost    0
# Branch            0
# Doctor_Name       0
# Length_of_Stay    0
# Readmitted        0
# Outcome           0
# dtype: int64

# %%
#saving the cleaned dataset
df.to_excel('cleaned_Desmond_Healthcare_Data_2024.xlsx', index=False)
